# %%
import pandas as pd

# %%
data_set=pd.read_csv('water_potability.csv')

# %%
from summarytools import dfSummary
dfSummary(data_set)
# Out:
# Feature: ph                                  |▉         | [  9%]   06:39 -> (1:06:37 left)
# Feature: ph                                  |▉         | [  9%]   04:00 -> (40:00 left)
# Feature: ph                                  |▉         | [  9%]   03:59 -> (39:50 left)
# <style type="text/css">
# #T_67f94 thead>tr>th {
#   text-align: left;
# }
# #T_67f94_row0_col0, #T_67f94_row1_col0, #T_67f94_row2_col0, #T_67f94_row3_col0, #T_67f94_row4_col0, #T_67f94_row5_col0, #T_67f94_row6_col0, #T_67f94_row7_col0, #T_67f94_row8_col0, #T_67f94_row9_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_67f94_row0_col1, #T_67f94_row1_col1, #T_67f94_row2_col1, #T_67f94_row3_col1, #T_67f94_row4_col1, #T_67f94_row5_col1, #T_67f94_row6_col1, #T_67f94_row7_col1, #T_67f94_row8_col1, #T_67f94_row9_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
# ...
